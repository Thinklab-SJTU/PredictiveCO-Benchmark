# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
prob_name = "knapsack-gen"
prefix = "default"
model_name = "mse"

# 创建一个箱线图
plt.figure(figsize=(10, 6))
ax = sns.boxplot(x=df['columns'], y=df.iloc[1], palette="Set2")

# for i, box in enumerate(ax.artists):
#     data_vals = [y for j, y in enumerate(data.iloc[:, i]) if j % 50 == 0]
#     std_val = np.std(data_vals)
#     ax.text(i, std_val + 0.1, f"Std: {std_val:.2f}", horizontalalignment='center')

# 可选：旋转x轴标签
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')

plt.title("Boxplot with Standard Deviation")
plt.show()
